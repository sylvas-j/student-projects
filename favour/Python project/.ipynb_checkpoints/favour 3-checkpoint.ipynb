# %%
import requests
import json

# %%
url='https://visual-crossing-weather.p.rapidapi.com/forecast'
city = input('Enter city name: ')
querystring = {'aggregateHours':'24','location':'Port Harcourt','contentType':'json','unitGroup':'uk','shortColumnNames':'0'}
headers = {'X-RapidAPI-Key':'ed83b86376msh226b6fe8b7c7194p15c0ccjsn215cf860ecc7','X-RapidAPI-Host':'visual-crossing-weather.p.rapidapi.com'}
response = requests.request('GET',url,headers=headers,params=querystring)
data=json.loads(response.text)
#print(json.dumps(data, indent=4))
data['locations']['Port Harcourt']['values']
# Out:
# [{'wdir': 139.2,
#   'uvindex': 3.5,
#   'datetimeStr': '2023-01-12T00:00:00+01:00',
#   'preciptype': '',
#   'cin': -32.5,
#   'cloudcover': 28.1,
#   'pop': 0.0,
#   'mint': 26.0,
#   'datetime': 1673481600000,
#   'precip': 0.0,
#   'solarradiation': 347.3,
#   'dew': 11.7,
#   'humidity': 37.0,
#   'temp': 31.3,
#   'maxt': 36.7,
#   'visibility': 15.0,
#   'wspd': 7.9,
#   'severerisk': 8.1,
#   'solarenergy': 1.3,
#   'heatindex': 34.2,
#   'snowdepth': 0.0,
#   'sealevelpressure': 1009.0,
#   'snow': 0.0,
#   'wgust': 18.6,
#   'conditions': 'Partially cloudy',
#   'windchill': None,
#   'cape': 105.0},
#  {'wdir': 191.3,
#   'uvindex': 2.7,
#   'datetimeStr': '2023-01-13T00:00:00+01:00',
#   'preciptype': '',
#   'cin': -77.4,
#   'cloudcover': 24.5,
#   'pop': 0.0,
#   'mint': 23.8,
#   'datetime': 1673568000000,
#   'precip': 0.0,
#   'solarradiation': 271.4,
#   'dew': 18.7,
#   'humidity': 59.7,
#   'temp': 28.8,
#   'maxt': 37.3,
#   'visibility': 15.0,
# ...

# %%
data=data['locations']['Port Harcourt']['values']    
for a, i in enumerate(data):
    if 'datetimeStr':
        print('precip',i['precip'])
        a+1
        if a==5:
            break
# Out:
# precip 0.0
# precip 0.0
# precip 0.0
# precip 0.6
# precip 0.0
# precip 0.1
